# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('customer_churn_dataset.csv')

# %%
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1970  5445-UTODQ  Female              0     Yes         No       7
# 125   4622-YNKIJ    Male              0      No         No      33
# 4959  7853-GVUDZ  Female              0     Yes        Yes       1
# 1880  6474-FVJLC    Male              0      No         No       2
# 1672  4737-AQCPU    Male              0     Yes        Yes      72
# 4651  3540-RZJYU  Female              0      No         No      15
# 894   7997-EASSD  Female              0     Yes         No      63
# 4133  2208-UGTGR    Male              0      No         No      56
# 1866  7940-UQQUG  Female              0     Yes        Yes      64
# 6125  0871-URUWO    Male              0     Yes         No      13
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 1970          Yes            No     Fiber optic                   No  ...
# 125           Yes            No     Fiber optic                  Yes  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df[df['TotalCharges']==' ']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
(df['TotalCharges']==' ').sum()
# Out:
# np.int64(11)

# %%
df[df['TotalCharges']==' ']['tenure']
# Out:
# 488     0
# 753     0
# 936     0
# 1082    0
# 1340    0
# 3331    0
# 3826    0
# 4380    0
# 5218    0
# 6670    0
# 6754    0
# Name: tenure, dtype: int64

# %%
df['TotalCharges']=df['TotalCharges'].replace(' ',0)
df['TotalCharges']=df['TotalCharges'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df[['tenure','MonthlyCharges','TotalCharges']]
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 0          1           29.85         29.85
# 1         34           56.95       1889.50
# 2          2           53.85        108.15
# 3         45           42.30       1840.75
# 4          2           70.70        151.65
# ...      ...             ...           ...
# 7038      24           84.80       1990.50
# 7039      72          103.20       7362.90
# 7040      11           29.60        346.45
# 7041       4           74.40        306.60
# 7042      66          105.65       6844.50
#
# [7043 rows x 3 columns]

# %%
df[['tenure','MonthlyCharges','TotalCharges']].corr()
# Out:
#                   tenure  MonthlyCharges  TotalCharges
# tenure          1.000000        0.247900      0.826178
# MonthlyCharges  0.247900        1.000000      0.651174
# TotalCharges    0.826178        0.651174      1.000000

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df[['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod']].nunique()
# Out:
# gender              2
# SeniorCitizen       2
# Partner             2
# Dependents          2
# PhoneService        2
# MultipleLines       3
# InternetService     3
# OnlineSecurity      3
# OnlineBackup        3
# DeviceProtection    3
# TechSupport         3
# StreamingTV         3
# StreamingMovies     3
# Contract            3
# PaperlessBilling    2
# PaymentMethod       4
# dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
pd.crosstab(df['Contract'],df['Churn'])
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
pd.crosstab(df['Contract'],df['Churn'],normalize='index')  ##
# Out:
# Churn                 No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %%
sns.countplot(x='Contract',hue='Churn',data=df)
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %%
df.groupby('Contract')['Churn'].value_counts(normalize=True)
# Out:
# Contract        Churn
# Month-to-month  No       0.572903
#                 Yes      0.427097
# One year        No       0.887305
#                 Yes      0.112695
# Two year        No       0.971681
#                 Yes      0.028319
# Name: proportion, dtype: float64

# %%
pd.crosstab(df['Contract'],df['Churn'],normalize='index')
# Out:
# Churn                 No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %% [markdown]
# ##Customers with month-to-month contracts show a churn rate of ~43%, compared to only ~2% for customers on two-year contracts. This suggests that contract commitment strongly influences churn behavior, with short-term contracts significantly increasing churn risk.

# %%
pd.crosstab(df['PaymentMethod'],df['Churn'],normalize='index')
# Out:
# Churn                            No       Yes
# PaymentMethod
# Bank transfer (automatic)  0.832902  0.167098
# Credit card (automatic)    0.847569  0.152431
# Electronic check           0.547146  0.452854
# Mailed check               0.808933  0.191067

# %%
pd.crosstab(df['PaperlessBilling'],df['Churn'],normalize='index')
# Out:
# Churn                   No       Yes
# PaperlessBilling
# No                0.836699  0.163301
# Yes               0.664349  0.335651

# %%
pd.crosstab(df['PaperlessBilling'],df['PaymentMethod'],normalize='index')
# Out:
# PaymentMethod     Bank transfer (automatic)  Credit card (automatic)  \
# PaperlessBilling
# No                                 0.227368                 0.222841
# Yes                                0.213618                 0.211460
#
# PaymentMethod     Electronic check  Mailed check
# PaperlessBilling
# No                        0.216922      0.332869
# Yes                       0.417646      0.157276

# %%
sns.histplot(data=df,x='tenure',bins=30,hue='Churn',kde=True)
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %%
sns.boxplot(data=df,y='tenure',x='Churn')
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %%
pd.crosstab(df['InternetService'], df['Churn'], normalize='index')
# Out:
# Churn                  No       Yes
# InternetService
# DSL              0.810409  0.189591
# Fiber optic      0.581072  0.418928
# No               0.925950  0.074050

# %%
df.groupby('InternetService')['MonthlyCharges'].mean()
# Out:
# InternetService
# DSL            58.102169
# Fiber optic    91.500129
# No             21.079194
# Name: MonthlyCharges, dtype: float64

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %%
df.groupby('Churn')['MonthlyCharges'].mean()
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
df[['MonthlyCharges','tenure','TotalCharges']].corr()
# Out:
#                 MonthlyCharges    tenure  TotalCharges
# MonthlyCharges        1.000000  0.247900      0.651174
# tenure                0.247900  1.000000      0.826178
# TotalCharges          0.651174  0.826178      1.000000

# %%
sns.heatmap(df[['MonthlyCharges','tenure','TotalCharges']].corr(),annot=True)
# Out:
# <Axes: >

# %%
pd.crosstab(df['SeniorCitizen'],df['Churn'],normalize=True)
# Out:
# Churn                No       Yes
# SeniorCitizen
# 0              0.640068  0.197785
# 1              0.094562  0.067585

# %%
df.groupby('Churn')['TotalCharges'].mean()
# Out:
# Churn
# No     2549.911442
# Yes    1531.796094
# Name: TotalCharges, dtype: float64

# %%
df.groupby('SeniorCitizen')['MonthlyCharges'].mean()
# Out:
# SeniorCitizen
# 0    61.847441
# 1    79.820359
# Name: MonthlyCharges, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
pd.crosstab(df['TechSupport'],df['Churn'],normalize='index')
# Out:
# Churn                      No       Yes
# TechSupport
# No                   0.583645  0.416355
# No internet service  0.925950  0.074050
# Yes                  0.848337  0.151663

# %%
df.groupby('MultipleLines')['Churn'].apply(lambda x: (x=='Yes').mean())
# Out:
# MultipleLines
# No                  0.250442
# No phone service    0.249267
# Yes                 0.286099
# Name: Churn, dtype: float64

# %%
pd.crosstab(df['MultipleLines'],df['Churn'],normalize='index')
# Out:
# Churn                   No       Yes
# MultipleLines
# No                0.749558  0.250442
# No phone service  0.750733  0.249267
# Yes               0.713901  0.286099

# %%
pd.crosstab(df['TechSupport'],df['Contract'],normalize='index')
# Out:
# Contract             Month-to-month  One year  Two year
# TechSupport
# No                         0.771667  0.160380  0.067953
# No internet service        0.343381  0.238532  0.418087
# Yes                        0.328278  0.270059  0.401663

# %%
binary_cols = [
    "Partner",
    "Dependents",
    "PhoneService",
    "PaperlessBilling"
]
for col in binary_cols:
    df[col]=df[col].map({'Yes':1,'No':0})

# %%
df['gender']=df['gender'].map({'Male':0,'Female':1})

# %%
df["Churn"] = df["Churn"].map({"No":0, "Yes":1})

# %%
X=df.drop(columns=['Churn','customerID'])

# %%
y=df['Churn']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
X_train.shape
# X_test.shape
# Out:
# (5634, 19)

# %%
num_features = ["tenure", "MonthlyCharges", "TotalCharges"]

cat_features = [
    "MultipleLines",
    "InternetService",
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies",
    "Contract",
    "PaymentMethod"
]

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer

# %%
preprocessor=ColumnTransformer(
    transformers=[
        ('num',StandardScaler(),num_features),
        ('cat',OneHotEncoder(handle_unknown='ignore'),cat_features)
    ],
    remainder='passthrough'
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
pipeline=Pipeline([
    ('preprocessing',preprocessor),
    ('model',LogisticRegression(max_iter=1000))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['tenure', 'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['MultipleLines',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
# ...

# %%
from sklearn.metrics import classification_report

y_pred = pipeline.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1035
#            1       0.66      0.56      0.61       374
#
#     accuracy                           0.81      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
from sklearn.metrics import roc_auc_score

y_prob = pipeline.predict_proba(X_test)[:,1]
roc_auc_score(y_test, y_prob)
# Out:
# 0.8420444857785011

# %%
import numpy as np

y_prob = pipeline.predict_proba(X_test)[:,1]
y_pred_new = (y_prob > 0.3).astype(int)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_new))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.75      0.81      1035
#            1       0.52      0.75      0.62       374
#
#     accuracy                           0.75      1409
#    macro avg       0.71      0.75      0.71      1409
# weighted avg       0.79      0.75      0.76      1409

# %%
feature_names=pipeline.named_steps['preprocessing'].get_feature_names_out()
coefficients=pipeline.named_steps['model'].coef_[0]
coef_df=pd.DataFrame({
    'feature':feature_names,
    'coefficient':coefficients
}).sort_values(by='coefficient',ascending=False)
coef_df.head(10)
# Out:
#                                 feature  coefficient
# 7      cat__InternetService_Fiber optic     0.591656
# 2                     num__TotalCharges     0.537976
# 27         cat__Contract_Month-to-month     0.530942
# 39          remainder__PaperlessBilling     0.369026
# 32  cat__PaymentMethod_Electronic check     0.162022
# 23                 cat__StreamingTV_Yes     0.154771
# 26             cat__StreamingMovies_Yes     0.154035
# 35             remainder__SeniorCitizen     0.142007
# 9                cat__OnlineSecurity_No     0.107299
# 5                cat__MultipleLines_Yes     0.103451

# %%
coef_df.tail(5)
# Out:
#                      feature  coefficient
# 8    cat__InternetService_No    -0.350369
# 1        num__MonthlyCharges    -0.600858
# 6   cat__InternetService_DSL    -0.702323
# 29    cat__Contract_Two year    -0.824013
# 0                num__tenure    -1.259767

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model=Pipeline([
    ('preprocessing',preprocessor),
    ('model',RandomForestClassifier(
        n_estimators=300,
        random_state=42
    ))
])

# %%
rf_model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['tenure', 'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['MultipleLines',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
# ...

# %%
y_pred=rf_model.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1035
#            1       0.61      0.49      0.55       374
#
#     accuracy                           0.78      1409
#    macro avg       0.72      0.69      0.70      1409
# weighted avg       0.77      0.78      0.77      1409

# %%
y_prob=rf_model.predict_proba(X_test)[:,1]
roc_auc_score(y_test,y_prob)
# Out:
# 0.8203350641969567

# %%
feature_names = rf_model.named_steps["preprocessing"].get_feature_names_out()
importances = rf_model.named_steps["model"].feature_importances_

import pandas as pd

rf_importance = pd.DataFrame({
    "feature": feature_names,
    "importance": importances
}).sort_values(by="importance", ascending=False)

rf_importance.head(10)
# Out:
#                                 feature  importance
# 2                     num__TotalCharges    0.169224
# 1                   num__MonthlyCharges    0.148288
# 0                           num__tenure    0.143607
# 27         cat__Contract_Month-to-month    0.051790
# 9                cat__OnlineSecurity_No    0.033985
# 32  cat__PaymentMethod_Electronic check    0.032227
# 18                  cat__TechSupport_No    0.030784
# 34                    remainder__gender    0.028001
# 7      cat__InternetService_Fiber optic    0.025982
# 39          remainder__PaperlessBilling    0.025445

# %%
from sklearn.metrics import roc_auc_score

train_prob = rf_model.predict_proba(X_train)[:,1]
test_prob = rf_model.predict_proba(X_test)[:,1]

print("Train AUC:", roc_auc_score(y_train, train_prob))
print("Test AUC:", roc_auc_score(y_test, test_prob))
# Out:
# Train AUC: 0.9999343062685395
# Test AUC: 0.8203350641969567

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    "model__n_estimators": [200, 300],
    "model__max_depth": [5, 10, 15],
    "model__min_samples_split": [2, 5],
    "model__min_samples_leaf": [1, 3]
}

# %%
grid = GridSearchCV(
    rf_model,
    param_grid,
    cv=5,
    scoring="roc_auc",
    n_jobs=-1
)

grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['tenure',
#                                                                           'MonthlyCharges',
#                                                                           'TotalCharges']),
#                                                                         ('cat',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['MultipleLines',
#                                                                           'InternetService',
# ...

# %%
grid.best_params_
# Out:
# {'model__max_depth': 10,
#  'model__min_samples_leaf': 3,
#  'model__min_samples_split': 2,
#  'model__n_estimators': 300}

# %%
best_rf = grid.best_estimator_

y_prob = best_rf.predict_proba(X_test)[:,1]

from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, y_prob)
# Out:
# 0.841756439071017

# %%
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline

xgb_model = Pipeline([
    ("preprocessing", preprocessor),
    ("model", XGBClassifier(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=4,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
        eval_metric="logloss"
    ))
])

# %%
xgb_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['tenure', 'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['MultipleLines',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
# ...

# %%
from sklearn.metrics import classification_report, roc_auc_score

y_pred = xgb_model.predict(X_test)
print(classification_report(y_test, y_pred))

y_prob = xgb_model.predict_proba(X_test)[:,1]
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1035
#            1       0.66      0.53      0.59       374
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.72      0.73      1409
# weighted avg       0.79      0.80      0.79      1409
#
# ROC-AUC: 0.8417021881216254

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_prob)

plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.show()

# %%
from sklearn.metrics import roc_curve

fpr, tpr, _ = roc_curve(y_test, y_prob)

plt.plot(fpr, tpr)
plt.plot([0,1],[0,1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.show()

# %%
pip install shap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import shap

# %%
feature_names = pipeline.named_steps["preprocessing"].get_feature_names_out()

# %%
import pandas as pd

X_test_transformed = pipeline.named_steps["preprocessing"].transform(X_test)

X_test_transformed_df = pd.DataFrame(
    X_test_transformed,
    columns=feature_names
)

# %%
explainer = shap.Explainer(pipeline.named_steps["model"], 
                           X_test_transformed_df)

# %%
shap_values = explainer(X_test_transformed_df)

# %%
shap.summary_plot(shap_values, X_test_transformed_df)

# %%
shap.plots.waterfall(shap_values[0])

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    pipeline,
    X,
    y,
    cv=5,
    scoring="roc_auc"
)

print(scores)
print("Mean AUC:", scores.mean())
# Out:
# [0.8582061  0.85858069 0.83307629 0.83806971 0.83889986]
# Mean AUC: 0.8453665301062261
