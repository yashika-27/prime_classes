# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
orders = pd.read_csv("olist_orders_dataset.csv")
customers = pd.read_csv("olist_customers_dataset.csv")
order_items = pd.read_csv("olist_order_items_dataset.csv")
payments = pd.read_csv("olist_order_payments_dataset.csv")
reviews = pd.read_csv("olist_order_reviews_dataset.csv")
products = pd.read_csv("olist_products_dataset.csv")
sellers = pd.read_csv("olist_sellers_dataset.csv")
geo = pd.read_csv("olist_geolocation_dataset.csv")

# %%
orders.shape[0]  #how big is the business
# Out:
# 99441

# %%
orders['order_status'].value_counts() #how many delivered and how much failed
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
customers['customer_unique_id'].nunique()  #total customers in business
# Out:
# 96096

# %%
merged=orders.merge(customers, on= 'customer_id')
merged.groupby('customer_unique_id')['order_id'].count().describe()  # average order per customer id
# Out:
# count    96096.000000
# mean         1.034809
# std          0.214384
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         17.000000
# Name: order_id, dtype: float64

# %%
order_counts=merged.groupby('customer_unique_id')['order_id'].count()
order_counts[order_counts>1]  # customer placed order more than one time
# Out:
# customer_unique_id
# 00172711b30d52eea8b313a7f2cced02    2
# 004288347e5e88a27ded2bb23747066c    2
# 004b45ec5c64187465168251cd1c9c2f    2
# 0058f300f57d7b93c477a131a59b36c3    2
# 00a39521eb40f7012db50455bf083460    2
#                                    ..
# ff36be26206fffe1eb37afd54c70e18b    3
# ff44401d0d8f5b9c54a47374eb48c1b8    2
# ff8892f7c26aa0446da53d01b18df463    2
# ff922bdd6bafcdf99cb90d7f39cea5b3    3
# ffe254cc039740e17dd15a5305035928    2
# Name: order_id, Length: 2997, dtype: int64

# %%
orders['order_purchase_timestamp']=pd.to_datetime(orders['order_purchase_timestamp'])
orders['order_delivered_customer_date']=pd.to_datetime(orders['order_delivered_customer_date'])
orders['delivery_time']=(
    orders['order_delivered_customer_date'] - orders['order_purchase_timestamp']
).dt.days
orders['delivery_time'].describe()   # time in delivery
# Out:
# count    96476.000000
# mean        12.094086
# std          9.551746
# min          0.000000
# 25%          6.000000
# 50%         10.000000
# 75%         15.000000
# max        209.000000
# Name: delivery_time, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(orders['delivery_time'], kde=True)

plt.axvline(orders['delivery_time'].mean(), linestyle='dashed')
plt.axvline(orders['delivery_time'].median(), linestyle='solid')

plt.title("Delivery Time Distribution")

plt.show()  #where lies the most delivery time ....distribution od delivery time, 0 to 10 days has maximum data after that decreased a lot

# %%
df=orders.merge(reviews, on= 'order_id')
df.groupby('review_score')['delivery_time'].mean() #average delivery time per review_score
# Out:
# review_score
# 1    20.849825
# 2    16.194832
# 3    13.795278
# 4    11.848054
# 5    10.224097
# Name: delivery_time, dtype: float64

# %%
df.groupby('review_score')['delivery_time'].describe() # distribution of delivery time over review score
# Out:
#                 count       mean        std  min  25%   50%   75%    max
# review_score
# 1              9409.0  20.849825  16.059046  0.0  9.0  16.0  30.0  195.0
# 2              2941.0  16.194832  12.486474  1.0  8.0  13.0  22.0  208.0
# 3              7962.0  13.795278   9.943568  0.0  7.0  12.0  18.0  188.0
# 4             18987.0  11.848054   8.291362  0.0  7.0  10.0  15.0  194.0
# 5             57060.0  10.224097   6.824501  0.0  6.0   9.0  13.0  187.0

# %%
orders['order_delivered_customer_date']=pd.to_datetime(orders['order_delivered_customer_date'])
orders['order_estimated_delivery_date']=pd.to_datetime(orders['order_estimated_delivery_date'])
orders['delivery_gap']=(
    orders['order_delivered_customer_date']-orders['order_estimated_delivery_date']
).dt.days
orders['delivery_delay'] = orders['delivery_gap'].apply(lambda x: x if x > 0 else 0)  #delivery delays
(orders['delivery_delay']>0).sum()
# Out:
# np.int64(6535)

# %%
late_orders = orders[orders['delivery_gap'] > 0]
(late_orders.shape[0] / orders[orders['order_status']=='delivered'].shape[0])*100  #out of all delivered order how much % is delayed
# Out:
# 6.773564957814217

# %%
late_orders['delivery_gap'].describe()  # 50% delay is 7 days and mean is 10 days which is still lot only 25% are under 3 days
# Out:
# count    6535.000000
# mean       10.620352
# std        14.643844
# min         1.000000
# 25%         3.000000
# 50%         7.000000
# 75%        13.000000
# max       188.000000
# Name: delivery_gap, dtype: float64

# %%
sns.histplot(late_orders['delivery_gap'],kde=True)
# Out:
# <Axes: xlabel='delivery_gap', ylabel='Count'>

# %%
order_items['price'].sum()  # total revenue
# Out:
# np.float64(13591643.7)

# %%
order_revenue = order_items.groupby('order_id')['price'].sum()

order_revenue.describe()  # revenue over per order
# Out:
# count    98666.000000
# mean       137.754076
# std        210.645145
# min          0.850000
# 25%         45.900000
# 50%         86.900000
# 75%        149.900000
# max      13440.000000
# Name: price, dtype: float64

# %%
df = orders.merge(customers, on='customer_id')
df = df.merge(order_items, on='order_id')

customer_revenue = df.groupby('customer_unique_id')['price'].sum()
customer_revenue.describe()  # revenue per customer
# Out:
# count    95420.000000
# mean       142.440198
# std        217.656355
# min          0.850000
# 25%         47.900000
# 50%         89.900000
# 75%        155.000000
# max      13440.000000
# Name: price, dtype: float64

# %%
df=order_items.merge(products,on='product_id')
df.groupby('product_category_name')['price'].sum().sort_values(ascending=False)  #which product driven the business,how much money made by each category
# Out:
# product_category_name
# beleza_saude                     1258681.34
# relogios_presentes               1205005.68
# cama_mesa_banho                  1036988.68
# esporte_lazer                     988048.97
# informatica_acessorios            911954.32
#                                     ...
# flores                              1110.04
# casa_conforto_2                      760.27
# cds_dvds_musicais                    730.00
# fashion_roupa_infanto_juvenil        569.85
# seguros_e_servicos                   283.29
# Name: price, Length: 73, dtype: float64

# %%
df = order_items.merge(products, on='product_id')

category_orders = df.groupby('product_category_name')['order_id'].count().sort_values(ascending=False)
category_orders  # order count per category to know which product drive the business most by its repeated order
# Out:
# product_category_name
# cama_mesa_banho                  11115
# beleza_saude                      9670
# esporte_lazer                     8641
# moveis_decoracao                  8334
# informatica_acessorios            7827
#                                  ...
# cds_dvds_musicais                   14
# la_cuisine                          14
# pc_gamer                             9
# fashion_roupa_infanto_juvenil        8
# seguros_e_servicos                   2
# Name: order_id, Length: 73, dtype: int64

# %%
category_price = df.groupby('product_category_name')['price'].mean()
category_price.sort_values(ascending=True)  # average amount made by per category , avg price of each product in the category
# Out:
# product_category_name
# casa_conforto_2                  25.342333
# flores                           33.637576
# fraldas_higiene                  40.194615
# cds_dvds_musicais                52.142857
# alimentos_bebidas                54.602446
#                                   ...
# instrumentos_musicais           281.616000
# agro_industria_e_comercio       342.124858
# eletrodomesticos_2              476.124958
# portateis_casa_forno_e_cafe     624.285658
# pcs                            1098.340542
# Name: price, Length: 73, dtype: float64

# %%
merge=orders.merge(reviews, on='order_id')
merge.groupby('review_score').agg({
    'delivery_delay': ['mean', 'median'],
    'order_id': 'count'
})  # late delivery implies bad reviews but not vise versa,as median=0 that means most of the orders delivered on time
# Out:
#              delivery_delay        order_id
#                        mean median    count
# review_score
# 1                  3.726278    0.0    11424
# 2                  1.805776    0.0     3151
# 3                  0.773077    0.0     8179
# 4                  0.286595    0.0    19142
# 5                  0.129239    0.0    57328
