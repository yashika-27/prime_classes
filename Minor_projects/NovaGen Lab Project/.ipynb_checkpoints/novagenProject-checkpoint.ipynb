# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('novagen_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9549 entries, 0 to 9548
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    9549 non-null   float64
#  1   BMI                    9549 non-null   float64
#  2   Blood_Pressure         9549 non-null   float64
#  3   Cholesterol            9549 non-null   float64
#  4   Glucose_Level          9549 non-null   float64
#  5   Heart_Rate             9549 non-null   float64
#  6   Sleep_Hours            9549 non-null   float64
#  7   Exercise_Hours         9549 non-null   float64
#  8   Water_Intake           9549 non-null   float64
#  9   Stress_Level           9549 non-null   float64
#  10  Target                 9549 non-null   int64
#  11  Smoking                9549 non-null   int64
#  12  Alcohol                9549 non-null   int64
#  13  Diet                   9549 non-null   int64
#  14  MentalHealth           9549 non-null   int64
#  15  PhysicalActivity       9549 non-null   int64
#  16  MedicalHistory         9549 non-null   int64
#  17  Allergies              9549 non-null   int64
#  18  Diet_Type__Vegan       9549 non-null   bool
#  19  Diet_Type__Vegetarian  9549 non-null   bool
#  20  Blood_Group_AB         9549 non-null   bool
#  21  Blood_Group_B          9549 non-null   bool
#  22  Blood_Group_O          9549 non-null   bool
# dtypes: bool(5), float64(10), int64(8)
# memory usage: 1.4 MB

# %%
cat_data=df.select_dtypes(include=['bool']).columns

# %%
cat_data
# Out:
# Index(['Diet_Type__Vegan', 'Diet_Type__Vegetarian', 'Blood_Group_AB',
#        'Blood_Group_B', 'Blood_Group_O'],
#       dtype='object')

# %%
df=pd.get_dummies(df,columns=cat_data,drop_first=True,dtype=int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9549 entries, 0 to 9548
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         9549 non-null   float64
#  1   BMI                         9549 non-null   float64
#  2   Blood_Pressure              9549 non-null   float64
#  3   Cholesterol                 9549 non-null   float64
#  4   Glucose_Level               9549 non-null   float64
#  5   Heart_Rate                  9549 non-null   float64
#  6   Sleep_Hours                 9549 non-null   float64
#  7   Exercise_Hours              9549 non-null   float64
#  8   Water_Intake                9549 non-null   float64
#  9   Stress_Level                9549 non-null   float64
#  10  Target                      9549 non-null   int64
#  11  Smoking                     9549 non-null   int64
#  12  Alcohol                     9549 non-null   int64
#  13  Diet                        9549 non-null   int64
#  14  MentalHealth                9549 non-null   int64
#  15  PhysicalActivity            9549 non-null   int64
#  16  MedicalHistory              9549 non-null   int64
#  17  Allergies                   9549 non-null   int64
#  18  Diet_Type__Vegan_True       9549 non-null   int64
#  19  Diet_Type__Vegetarian_True  9549 non-null   int64
#  20  Blood_Group_AB_True         9549 non-null   int64
#  21  Blood_Group_B_True          9549 non-null   int64
#  22  Blood_Group_O_True          9549 non-null   int64
# dtypes: float64(10), int64(13)
# memory usage: 1.7 MB

# %%
X=df.drop(columns='Target')
y=df['Target']

# %%
X_train,X_test,y_train,y_test=train_test_split(
    X,y,test_size=0.2,stratify=y,random_state=42
)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model =DecisionTreeClassifier()
model.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred=model.predict(X_test_scaled)
y_train_pred=model.predict(X_train_scaled)
print('train accuracy : ',accuracy_score(y_train,y_train_pred))
print('test accuracy : ',accuracy_score(y_test,y_pred))
# Out:
# train accuracy :  1.0
# test accuracy :  0.8958115183246074

# %%
# Check for logistic

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(
    penalty='l2',
    max_iter=5000
)
lr.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
y_pred=lr.predict(X_test_scaled)
y_train_pred=lr.predict(X_train_scaled)
print('train accuracy : ',accuracy_score(y_train,y_train_pred))
print('test accuracy : ',accuracy_score(y_test,y_pred))
# Out:
# train accuracy :  0.8175153815944496
# test accuracy :  0.8136125654450261

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(
    n_neighbors=5,
    metric="euclidean"
)

knn.fit(X_train_scaled, y_train)

y_pred_knn = knn.predict(X_test_scaled)

print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.8832460732984293

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(
    n_estimators=601,
    oob_score=True,
    max_depth=None
)
rf.fit(X_train_scaled,y_train)
y_pred=rf.predict(X_test_scaled)
print('OOB Score : ',rf.oob_score_)
print('accuracy : ',accuracy_score(y_test,y_pred))
# Out:
# OOB Score :  0.9388663437622725
# accuracy :  0.9403141361256544

# %%
from sklearn.ensemble import VotingClassifier
lr=LogisticRegression(max_iter=5000)
vc=VotingClassifier(
    estimators=[
        ('lr',lr),
        ('rf',rf),
        ('knn',knn)
    ]
)

# %%
vc.fit(X_train_scaled,y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression(max_iter=5000)),
#                              ('rf',
#                               RandomForestClassifier(n_estimators=601,
#                                                      oob_score=True)),
#                              ('knn', KNeighborsClassifier(metric='euclidean'))])

# %%
y_pred=vc.predict(X_test_scaled)
print('accuracy : ',accuracy_score(y_test,y_pred))
# Out:
# accuracy :  0.9261780104712042
